# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %%
#Create a set of 2,000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
#Get the nearest city using the citipy module.
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 745

# %%
#Perform an API call with the OpenWeatherMap.
#Import dependencies
import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Retrieve the following information from the API call:

#Latitude and longitude
#Maximum temperature
#Percent humidity
#Percent cloudiness
#Wind speed
#Weather description (for example, clouds, fog, light rain, clear sky)

city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | atuona
# Processing Record 2 of Set 1 | bambous virieux
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | deputatskiy
# Processing Record 5 of Set 1 | longyearbyen
# Processing Record 6 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | iqaluit
# Processing Record 9 of Set 1 | sungaipenuh
# Processing Record 10 of Set 1 | kaseda
# Processing Record 11 of Set 1 | brokopondo
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | sitka
# Processing Record 14 of Set 1 | lebu
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | fortuna
# Processing Record 17 of Set 1 | artyk
# City not found. Skipping...
# Processing Record 18 of Set 1 | emerald
# Processing Record 19 of Set 1 | jamestown
# Processing Record 20 of Set 1 | souillac
# Processing Record 21 of Set 1 | pyay
# Processing Record 22 of Set 1 | maxixe
# Processing Record 23 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | tasiilaq
# Processing Record 26 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 1 | saint george
# Processing Record 28 of Set 1 | provideniya
# Processing Record 29 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 1 | kununurra
# Processing Record 31 of Set 1 | avera
# Processing Record 32 of Set 1 | winnemucca
# Processing Record 33 of Set 1 | pevek
# Processing Record 34 of Set 1 | port alfred
# Processing Record 35 of Set 1 | cabo san lucas
# Processing Record 36 of Set 1 | thinadhoo
# Processing Record 37 of Set 1 | asayita
# City not found. Skipping...
# Processing Record 38 of Set 1 | rikitea
# Processing Record 39 of Set 1 | new norfolk
# Processing Record 40 of Set 1 | anadyr
# Processing Record 41 of Set 1 | puerto ayora
# Processing Record 42 of Set 1 | salalah
# Processing Record 43 of Set 1 | hithadhoo
# Processing Record 44 of Set 1 | tevaitoa
# Processing Record 45 of Set 1 | butaritari
# Processing Record 46 of Set 1 | ushuaia
# Processing Record 47 of Set 1 | bol
# Processing Record 48 of Set 1 | lima
# Processing Record 49 of Set 1 | tete
# Processing Record 50 of Set 1 | mangrol
# Processing Record 1 of Set 2 | moquegua
# Processing Record 2 of Set 2 | hohhot
# Processing Record 3 of Set 2 | moron
# Processing Record 4 of Set 2 | necochea
# Processing Record 5 of Set 2 | ribeira grande
# Processing Record 6 of Set 2 | kodiak
# Processing Record 7 of Set 2 | alice springs
# Processing Record 8 of Set 2 | ndjole
# Processing Record 9 of Set 2 | castro
# Processing Record 10 of Set 2 | kismayo
# Processing Record 11 of Set 2 | xining
# Processing Record 12 of Set 2 | omsukchan
# Processing Record 13 of Set 2 | carbonia
# Processing Record 14 of Set 2 | gat
# Processing Record 15 of Set 2 | santa isabel do rio negro
# Processing Record 16 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 17 of Set 2 | hirara
# Processing Record 18 of Set 2 | marsabit
# Processing Record 19 of Set 2 | manokwari
# Processing Record 20 of Set 2 | luwingu
# Processing Record 21 of Set 2 | bethel
# Processing Record 22 of Set 2 | buala
# Processing Record 23 of Set 2 | brae
# Processing Record 24 of Set 2 | qaanaaq
# Processing Record 25 of Set 2 | clyde river
# Processing Record 26 of Set 2 | daru
# Processing Record 27 of Set 2 | bluff
# Processing Record 28 of Set 2 | craig
# Processing Record 29 of Set 2 | mae hong son
# Processing Record 30 of Set 2 | kjollefjord
# Processing Record 31 of Set 2 | cayenne
# Processing Record 32 of Set 2 | victoria
# Processing Record 33 of Set 2 | santa rosa
# Processing Record 34 of Set 2 | nokaneng
# Processing Record 35 of Set 2 | buqayq
# City not found. Skipping...
# Processing Record 36 of Set 2 | barrow
# Processing Record 37 of Set 2 | norman wells
# Processing Record 38 of Set 2 | dabola
# Processing Record 39 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 2 | pacifica
# Processing Record 41 of Set 2 | zhigansk
# Processing Record 42 of Set 2 | tommot
# Processing Record 43 of Set 2 | moranbah
# Processing Record 44 of Set 2 | aybak
# City not found. Skipping...
# Processing Record 45 of Set 2 | avarua
# Processing Record 46 of Set 2 | bell ville
# Processing Record 47 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 48 of Set 2 | west helena
# Processing Record 49 of Set 2 | tuatapere
# Processing Record 50 of Set 2 | katsuura
# Processing Record 1 of Set 3 | arraial do cabo
# Processing Record 2 of Set 3 | broome
# Processing Record 3 of Set 3 | haines junction
# Processing Record 4 of Set 3 | coahuayana
# Processing Record 5 of Set 3 | mar del plata
# Processing Record 6 of Set 3 | ineu
# Processing Record 7 of Set 3 | yusva
# City not found. Skipping...
# Processing Record 8 of Set 3 | nome
# Processing Record 9 of Set 3 | el tigre
# Processing Record 10 of Set 3 | yulara
# Processing Record 11 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 3 | shimanovsk
# Processing Record 13 of Set 3 | road town
# Processing Record 14 of Set 3 | kutum
# Processing Record 15 of Set 3 | pochutla
# Processing Record 16 of Set 3 | hilo
# Processing Record 17 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 3 | hartford
# Processing Record 19 of Set 3 | nelson bay
# Processing Record 20 of Set 3 | ponta do sol
# Processing Record 21 of Set 3 | acapulco
# Processing Record 22 of Set 3 | marsa matruh
# Processing Record 23 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 24 of Set 3 | ostrovnoy
# Processing Record 25 of Set 3 | mutsu
# Processing Record 26 of Set 3 | miles city
# Processing Record 27 of Set 3 | the valley
# Processing Record 28 of Set 3 | riyadh
# Processing Record 29 of Set 3 | turukhansk
# Processing Record 30 of Set 3 | kaitangata
# Processing Record 31 of Set 3 | asau
# Processing Record 32 of Set 3 | dikson
# Processing Record 33 of Set 3 | praia da vitoria
# Processing Record 34 of Set 3 | east london
# Processing Record 35 of Set 3 | vaini
# Processing Record 36 of Set 3 | zdvinsk
# Processing Record 37 of Set 3 | thompson
# Processing Record 38 of Set 3 | upernavik
# Processing Record 39 of Set 3 | muros
# Processing Record 40 of Set 3 | obihiro
# Processing Record 41 of Set 3 | broken hill
# Processing Record 42 of Set 3 | makinsk
# Processing Record 43 of Set 3 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 44 of Set 3 | mandera
# Processing Record 45 of Set 3 | oktyabrskoye
# Processing Record 46 of Set 3 | ahuimanu
# Processing Record 47 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 48 of Set 3 | tual
# Processing Record 49 of Set 3 | port elizabeth
# Processing Record 50 of Set 3 | brazzaville
# Processing Record 1 of Set 4 | hermanus
# Processing Record 2 of Set 4 | puri
# Processing Record 3 of Set 4 | san andres
# Processing Record 4 of Set 4 | chapais
# Processing Record 5 of Set 4 | saint-philippe
# Processing Record 6 of Set 4 | havre-saint-pierre
# Processing Record 7 of Set 4 | rocha
# Processing Record 8 of Set 4 | kroya
# Processing Record 9 of Set 4 | sorland
# Processing Record 10 of Set 4 | togur
# Processing Record 11 of Set 4 | navoi
# Processing Record 12 of Set 4 | kabompo
# Processing Record 13 of Set 4 | orikum
# Processing Record 14 of Set 4 | dongkan
# Processing Record 15 of Set 4 | sivaki
# Processing Record 16 of Set 4 | luderitz
# Processing Record 17 of Set 4 | gamba
# Processing Record 18 of Set 4 | alta floresta
# Processing Record 19 of Set 4 | sao joao da barra
# Processing Record 20 of Set 4 | lavrentiya
# Processing Record 21 of Set 4 | najran
# Processing Record 22 of Set 4 | srednekolymsk
# Processing Record 23 of Set 4 | bredasdorp
# Processing Record 24 of Set 4 | fresno
# Processing Record 25 of Set 4 | sortland
# Processing Record 26 of Set 4 | sumbawa
# City not found. Skipping...
# Processing Record 27 of Set 4 | husavik
# Processing Record 28 of Set 4 | kapaa
# Processing Record 29 of Set 4 | bengkulu
# Processing Record 30 of Set 4 | airai
# Processing Record 31 of Set 4 | cranbrook
# Processing Record 32 of Set 4 | le port
# Processing Record 33 of Set 4 | yellowknife
# Processing Record 34 of Set 4 | kudahuvadhoo
# Processing Record 35 of Set 4 | mitsamiouli
# Processing Record 36 of Set 4 | krasnoselkup
# Processing Record 37 of Set 4 | erenhot
# Processing Record 38 of Set 4 | pisco
# Processing Record 39 of Set 4 | saldanha
# Processing Record 40 of Set 4 | mahebourg
# Processing Record 41 of Set 4 | gerash
# Processing Record 42 of Set 4 | mullaitivu
# City not found. Skipping...
# Processing Record 43 of Set 4 | lazarev
# Processing Record 44 of Set 4 | pangai
# Processing Record 45 of Set 4 | te anau
# Processing Record 46 of Set 4 | waverley
# Processing Record 47 of Set 4 | khatanga
# Processing Record 48 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 4 | freetown
# Processing Record 50 of Set 4 | umm lajj
# Processing Record 1 of Set 5 | gimbi
# Processing Record 2 of Set 5 | kuhdasht
# Processing Record 3 of Set 5 | dese
# Processing Record 4 of Set 5 | mount gambier
# Processing Record 5 of Set 5 | kruisfontein
# Processing Record 6 of Set 5 | boromo
# Processing Record 7 of Set 5 | atagay
# Processing Record 8 of Set 5 | talnakh
# Processing Record 9 of Set 5 | oranjestad
# Processing Record 10 of Set 5 | alofi
# Processing Record 11 of Set 5 | jacqueville
# Processing Record 12 of Set 5 | nova serrana
# Processing Record 13 of Set 5 | oktyabrskiy
# Processing Record 14 of Set 5 | hobart
# Processing Record 15 of Set 5 | amravati
# Processing Record 16 of Set 5 | leningradskiy
# Processing Record 17 of Set 5 | pacific grove
# Processing Record 18 of Set 5 | georgetown
# Processing Record 19 of Set 5 | tuktoyaktuk
# Processing Record 20 of Set 5 | puqi
# Processing Record 21 of Set 5 | saint anthony
# Processing Record 22 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 5 | kieta
# Processing Record 24 of Set 5 | flinders
# Processing Record 25 of Set 5 | guerrero negro
# Processing Record 26 of Set 5 | severomorsk
# Processing Record 27 of Set 5 | sakakah
# Processing Record 28 of Set 5 | buraydah
# Processing Record 29 of Set 5 | genhe
# Processing Record 30 of Set 5 | high level
# Processing Record 31 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 5 | talara
# Processing Record 33 of Set 5 | batemans bay
# Processing Record 34 of Set 5 | goderich
# Processing Record 35 of Set 5 | lethem
# Processing Record 36 of Set 5 | leshukonskoye
# Processing Record 37 of Set 5 | funza
# Processing Record 38 of Set 5 | neiafu
# Processing Record 39 of Set 5 | parian dakula
# Processing Record 40 of Set 5 | sobolevo
# Processing Record 41 of Set 5 | mikun
# Processing Record 42 of Set 5 | caravelas
# Processing Record 43 of Set 5 | nabire
# Processing Record 44 of Set 5 | hamilton
# Processing Record 45 of Set 5 | saint-leu
# Processing Record 46 of Set 5 | gizo
# Processing Record 47 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 5 | timmins
# Processing Record 49 of Set 5 | lorengau
# Processing Record 50 of Set 5 | petauke
# Processing Record 1 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 6 | tahta
# Processing Record 3 of Set 6 | dukat
# Processing Record 4 of Set 6 | abu dhabi
# Processing Record 5 of Set 6 | suntar
# Processing Record 6 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 6 | zhuzhou
# Processing Record 8 of Set 6 | katangli
# Processing Record 9 of Set 6 | matara
# Processing Record 10 of Set 6 | cidreira
# Processing Record 11 of Set 6 | huaicheng
# Processing Record 12 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 6 | terrace
# Processing Record 14 of Set 6 | taldan
# Processing Record 15 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 16 of Set 6 | araouane
# Processing Record 17 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 18 of Set 6 | roma
# Processing Record 19 of Set 6 | aklavik
# Processing Record 20 of Set 6 | krasnyy chikoy
# Processing Record 21 of Set 6 | neijiang
# Processing Record 22 of Set 6 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 6 | porterville
# Processing Record 24 of Set 6 | nouadhibou
# Processing Record 25 of Set 6 | geraldton
# Processing Record 26 of Set 6 | diamantino
# Processing Record 27 of Set 6 | rio gallegos
# Processing Record 28 of Set 6 | mogwase
# Processing Record 29 of Set 6 | port moresby
# Processing Record 30 of Set 6 | quang ngai
# Processing Record 31 of Set 6 | shumskiy
# Processing Record 32 of Set 6 | gbarnga
# Processing Record 33 of Set 6 | cherskiy
# Processing Record 34 of Set 6 | kayes
# Processing Record 35 of Set 6 | margate
# Processing Record 36 of Set 6 | nara
# Processing Record 37 of Set 6 | isangel
# Processing Record 38 of Set 6 | northam
# Processing Record 39 of Set 6 | nikolskoye
# Processing Record 40 of Set 6 | sassandra
# Processing Record 41 of Set 6 | porto velho
# Processing Record 42 of Set 6 | saskylakh
# Processing Record 43 of Set 6 | snezhnogorsk
# Processing Record 44 of Set 6 | seoul
# Processing Record 45 of Set 6 | beringovskiy
# Processing Record 46 of Set 6 | kavaratti
# Processing Record 47 of Set 6 | tigil
# Processing Record 48 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 49 of Set 6 | chumikan
# Processing Record 50 of Set 6 | alto araguaia
# Processing Record 1 of Set 7 | tautira
# Processing Record 2 of Set 7 | polunochnoye
# Processing Record 3 of Set 7 | itupiranga
# Processing Record 4 of Set 7 | yokadouma
# Processing Record 5 of Set 7 | ikom
# Processing Record 6 of Set 7 | antofagasta
# Processing Record 7 of Set 7 | nan
# Processing Record 8 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 7 | piacabucu
# Processing Record 10 of Set 7 | waipawa
# Processing Record 11 of Set 7 | innisfail
# Processing Record 12 of Set 7 | hun
# Processing Record 13 of Set 7 | marawi
# Processing Record 14 of Set 7 | hay river
# Processing Record 15 of Set 7 | ilulissat
# Processing Record 16 of Set 7 | maumere
# Processing Record 17 of Set 7 | redcliffe
# Processing Record 18 of Set 7 | port lincoln
# Processing Record 19 of Set 7 | half moon bay
# Processing Record 20 of Set 7 | mount isa
# Processing Record 21 of Set 7 | severo-kurilsk
# Processing Record 22 of Set 7 | mae sai
# Processing Record 23 of Set 7 | namatanai
# Processing Record 24 of Set 7 | hobyo
# Processing Record 25 of Set 7 | lagoa
# Processing Record 26 of Set 7 | andenes
# Processing Record 27 of Set 7 | joacaba
# Processing Record 28 of Set 7 | sambava
# Processing Record 29 of Set 7 | tiksi
# Processing Record 30 of Set 7 | walvis bay
# Processing Record 31 of Set 7 | semypolky
# Processing Record 32 of Set 7 | codrington
# Processing Record 33 of Set 7 | along
# Processing Record 34 of Set 7 | usinsk
# Processing Record 35 of Set 7 | namwala
# Processing Record 36 of Set 7 | coquimbo
# Processing Record 37 of Set 7 | charlestown
# Processing Record 38 of Set 7 | meulaboh
# Processing Record 39 of Set 7 | montceau-les-mines
# Processing Record 40 of Set 7 | sibu
# Processing Record 41 of Set 7 | brigham city
# Processing Record 42 of Set 7 | birjand
# Processing Record 43 of Set 7 | ahmadpur east
# Processing Record 44 of Set 7 | carnarvon
# Processing Record 45 of Set 7 | chuy
# Processing Record 46 of Set 7 | klaksvik
# Processing Record 47 of Set 7 | hvammstangi
# City not found. Skipping...
# Processing Record 48 of Set 7 | ondorhaan
# City not found. Skipping...
# Processing Record 49 of Set 7 | mbarara
# Processing Record 50 of Set 7 | mastung
# Processing Record 1 of Set 8 | windhoek
# Processing Record 2 of Set 8 | portland
# Processing Record 3 of Set 8 | chokurdakh
# Processing Record 4 of Set 8 | hualmay
# Processing Record 5 of Set 8 | pathein
# Processing Record 6 of Set 8 | zykovo
# Processing Record 7 of Set 8 | tabukiniberu
# City not found. Skipping...
# Processing Record 8 of Set 8 | coihaique
# Processing Record 9 of Set 8 | kropotkin
# Processing Record 10 of Set 8 | shahr-e kord
# Processing Record 11 of Set 8 | hami
# Processing Record 12 of Set 8 | turbo
# Processing Record 13 of Set 8 | forbes
# Processing Record 14 of Set 8 | qaqortoq
# Processing Record 15 of Set 8 | susehri
# Processing Record 16 of Set 8 | camalu
# Processing Record 17 of Set 8 | jiangyou
# Processing Record 18 of Set 8 | sulurpeta
# City not found. Skipping...
# Processing Record 19 of Set 8 | nanyamba
# Processing Record 20 of Set 8 | inhambane
# Processing Record 21 of Set 8 | saint paul
# Processing Record 22 of Set 8 | lasa
# Processing Record 23 of Set 8 | bubaque
# Processing Record 24 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 25 of Set 8 | pa sang
# Processing Record 26 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 27 of Set 8 | tangshan
# Processing Record 28 of Set 8 | inongo
# Processing Record 29 of Set 8 | adrar
# Processing Record 30 of Set 8 | hemsedal
# Processing Record 31 of Set 8 | kasongo-lunda
# Processing Record 32 of Set 8 | celestun
# Processing Record 33 of Set 8 | yangambi
# Processing Record 34 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 35 of Set 8 | port keats
# Processing Record 36 of Set 8 | vanimo
# Processing Record 37 of Set 8 | alyangula
# Processing Record 38 of Set 8 | hasaki
# Processing Record 39 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 40 of Set 8 | nago
# Processing Record 41 of Set 8 | atherton
# Processing Record 42 of Set 8 | ewa beach
# Processing Record 43 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 8 | lisakovsk
# Processing Record 45 of Set 8 | lompoc
# Processing Record 46 of Set 8 | cervo
# Processing Record 47 of Set 8 | albufeira
# Processing Record 48 of Set 8 | mokrousovo
# Processing Record 49 of Set 8 | nuuk
# Processing Record 50 of Set 8 | beian
# Processing Record 1 of Set 9 | pulandian
# Processing Record 2 of Set 9 | shelton
# Processing Record 3 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 4 of Set 9 | morondava
# Processing Record 5 of Set 9 | padang
# Processing Record 6 of Set 9 | mbini
# Processing Record 7 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 8 of Set 9 | kirakira
# Processing Record 9 of Set 9 | ukholovo
# Processing Record 10 of Set 9 | dingle
# Processing Record 11 of Set 9 | safranbolu
# Processing Record 12 of Set 9 | constitucion
# Processing Record 13 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 14 of Set 9 | ubrique
# Processing Record 15 of Set 9 | kedrovoye
# Processing Record 16 of Set 9 | vardo
# Processing Record 17 of Set 9 | aswan
# Processing Record 18 of Set 9 | papara
# Processing Record 19 of Set 9 | ankpa
# Processing Record 20 of Set 9 | san jose
# Processing Record 21 of Set 9 | rodrigues alves
# Processing Record 22 of Set 9 | kerteh
# City not found. Skipping...
# Processing Record 23 of Set 9 | kahului
# Processing Record 24 of Set 9 | puquio
# Processing Record 25 of Set 9 | tambul
# City not found. Skipping...
# Processing Record 26 of Set 9 | kerman
# Processing Record 27 of Set 9 | bongandanga
# Processing Record 28 of Set 9 | dongsheng
# Processing Record 29 of Set 9 | port macquarie
# Processing Record 30 of Set 9 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 31 of Set 9 | mimongo
# Processing Record 32 of Set 9 | aykhal
# Processing Record 33 of Set 9 | ambilobe
# Processing Record 34 of Set 9 | taybad
# Processing Record 35 of Set 9 | belmonte
# Processing Record 36 of Set 9 | santa maria
# Processing Record 37 of Set 9 | naliya
# Processing Record 38 of Set 9 | molo
# Processing Record 39 of Set 9 | harper
# Processing Record 40 of Set 9 | urumqi
# Processing Record 41 of Set 9 | yoichi
# Processing Record 42 of Set 9 | porto walter
# Processing Record 43 of Set 9 | hofn
# Processing Record 44 of Set 9 | gbadolite
# Processing Record 45 of Set 9 | ahipara
# Processing Record 46 of Set 9 | pryyutivka
# Processing Record 47 of Set 9 | sola
# Processing Record 48 of Set 9 | jutai
# Processing Record 49 of Set 9 | cockburn town
# Processing Record 50 of Set 9 | nha trang
# Processing Record 1 of Set 10 | miandrivazo
# Processing Record 2 of Set 10 | namibe
# Processing Record 3 of Set 10 | tura
# Processing Record 4 of Set 10 | vila
# Processing Record 5 of Set 10 | anzio
# Processing Record 6 of Set 10 | richards bay
# Processing Record 7 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 8 of Set 10 | salinopolis
# Processing Record 9 of Set 10 | ormara
# Processing Record 10 of Set 10 | lumberton
# Processing Record 11 of Set 10 | oxford
# Processing Record 12 of Set 10 | sahbuz
# Processing Record 13 of Set 10 | chimore
# Processing Record 14 of Set 10 | port hedland
# Processing Record 15 of Set 10 | oistins
# Processing Record 16 of Set 10 | lata
# Processing Record 17 of Set 10 | the pas
# Processing Record 18 of Set 10 | sioux lookout
# Processing Record 19 of Set 10 | narsaq
# Processing Record 20 of Set 10 | hassleholm
# Processing Record 21 of Set 10 | atambua
# Processing Record 22 of Set 10 | zhanaozen
# Processing Record 23 of Set 10 | toronto
# Processing Record 24 of Set 10 | manuk mangkaw
# Processing Record 25 of Set 10 | faanui
# Processing Record 26 of Set 10 | tapaua
# City not found. Skipping...
# Processing Record 27 of Set 10 | severnoye
# Processing Record 28 of Set 10 | okaihau
# Processing Record 29 of Set 10 | atar
# Processing Record 30 of Set 10 | tadine
# Processing Record 31 of Set 10 | jumla
# Processing Record 32 of Set 10 | adelaide
# Processing Record 33 of Set 10 | ukiah
# Processing Record 34 of Set 10 | kavieng
# Processing Record 35 of Set 10 | lazaro cardenas
# Processing Record 36 of Set 10 | hvolsvollur
# Processing Record 37 of Set 10 | sumenep
# Processing Record 38 of Set 10 | shamkhal
# Processing Record 39 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 40 of Set 10 | anchorage
# Processing Record 41 of Set 10 | banjarmasin
# Processing Record 42 of Set 10 | naze
# Processing Record 43 of Set 10 | torbay
# Processing Record 44 of Set 10 | ponta delgada
# Processing Record 45 of Set 10 | ulaanbaatar
# Processing Record 46 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 47 of Set 10 | ballina
# Processing Record 48 of Set 10 | oussouye
# Processing Record 49 of Set 10 | ucluelet
# Processing Record 50 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 1 of Set 11 | nacala
# Processing Record 2 of Set 11 | hervey bay
# Processing Record 3 of Set 11 | evensk
# Processing Record 4 of Set 11 | crateus
# Processing Record 5 of Set 11 | diglur
# Processing Record 6 of Set 11 | miyako
# Processing Record 7 of Set 11 | karasjok
# Processing Record 8 of Set 11 | lukulu
# Processing Record 9 of Set 11 | bayan
# Processing Record 10 of Set 11 | berlevag
# Processing Record 11 of Set 11 | tromso
# Processing Record 12 of Set 11 | bairiki
# Processing Record 13 of Set 11 | filingue
# Processing Record 14 of Set 11 | jian
# Processing Record 15 of Set 11 | tibu
# Processing Record 16 of Set 11 | saryg-sep
# Processing Record 17 of Set 11 | nandyal
# Processing Record 18 of Set 11 | bilibino
# Processing Record 19 of Set 11 | vao
# Processing Record 20 of Set 11 | freeport
# Processing Record 21 of Set 11 | ketchikan
# Processing Record 22 of Set 11 | minab
# Processing Record 23 of Set 11 | arkhara
# Processing Record 24 of Set 11 | burnie
# Processing Record 25 of Set 11 | prince rupert
# Processing Record 26 of Set 11 | michigan city
# Processing Record 27 of Set 11 | komsomolskiy
# Processing Record 28 of Set 11 | los llanos de aridane
# Processing Record 29 of Set 11 | antalaha
# Processing Record 30 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 31 of Set 11 | mason city
# Processing Record 32 of Set 11 | iskateley
# Processing Record 33 of Set 11 | novocherkassk
# Processing Record 34 of Set 11 | paamiut
# Processing Record 35 of Set 11 | vila franca do campo
# Processing Record 36 of Set 11 | sungairaya
# Processing Record 37 of Set 11 | laguna
# Processing Record 38 of Set 11 | taltal
# Processing Record 39 of Set 11 | zhuanghe
# Processing Record 40 of Set 11 | port blair
# Processing Record 41 of Set 11 | edd
# Processing Record 42 of Set 11 | smithers
# Processing Record 43 of Set 11 | troitskoye
# Processing Record 44 of Set 11 | duz
# City not found. Skipping...
# Processing Record 45 of Set 11 | basco
# Processing Record 46 of Set 11 | hansot
# Processing Record 47 of Set 11 | newport
# Processing Record 48 of Set 11 | boguchany
# Processing Record 49 of Set 11 | vanavara
# Processing Record 50 of Set 11 | shihezi
# Processing Record 1 of Set 12 | salo
# Processing Record 2 of Set 12 | yarada
# Processing Record 3 of Set 12 | nadterechnoye
# Processing Record 4 of Set 12 | faisalabad
# Processing Record 5 of Set 12 | esperance
# Processing Record 6 of Set 12 | san patricio
# Processing Record 7 of Set 12 | havoysund
# Processing Record 8 of Set 12 | doha
# Processing Record 9 of Set 12 | plettenberg bay
# Processing Record 10 of Set 12 | bull savanna
# Processing Record 11 of Set 12 | diego de almagro
# Processing Record 12 of Set 12 | maniitsoq
# Processing Record 13 of Set 12 | eisenberg
# Processing Record 14 of Set 12 | cootamundra
# Processing Record 15 of Set 12 | la palma
# Processing Record 16 of Set 12 | bahir dar
# Processing Record 17 of Set 12 | usuki
# Processing Record 18 of Set 12 | rapid valley
# Processing Record 19 of Set 12 | bathsheba
# Processing Record 20 of Set 12 | boa vista
# Processing Record 21 of Set 12 | mocuba
# Processing Record 22 of Set 12 | murgab
# Processing Record 23 of Set 12 | zhangye
# Processing Record 24 of Set 12 | novikovo
# Processing Record 25 of Set 12 | termoli
# Processing Record 26 of Set 12 | yekaterinogradskaya
# Processing Record 27 of Set 12 | hurghada
# Processing Record 28 of Set 12 | betioky
# Processing Record 29 of Set 12 | armizonskoye
# Processing Record 30 of Set 12 | whyalla
# Processing Record 31 of Set 12 | malaya purga
# Processing Record 32 of Set 12 | moose factory
# Processing Record 33 of Set 12 | poum
# Processing Record 34 of Set 12 | weligama
# Processing Record 35 of Set 12 | butea
# Processing Record 36 of Set 12 | solnechnyy
# Processing Record 37 of Set 12 | sao sebastiao
# Processing Record 38 of Set 12 | brezno
# Processing Record 39 of Set 12 | terme
# Processing Record 40 of Set 12 | morgan city
# Processing Record 41 of Set 12 | gushikawa
# Processing Record 42 of Set 12 | rassvet
# Processing Record 43 of Set 12 | grand gaube
# Processing Record 44 of Set 12 | lexington
# Processing Record 45 of Set 12 | raudeberg
# Processing Record 46 of Set 12 | lurgan
# Processing Record 47 of Set 12 | sinnamary
# Processing Record 48 of Set 12 | madaba
# Processing Record 49 of Set 12 | la peca
# Processing Record 50 of Set 12 | kenai
# Processing Record 1 of Set 13 | beaverlodge
# Processing Record 2 of Set 13 | nioro
# Processing Record 3 of Set 13 | livingstonia
# Processing Record 4 of Set 13 | marigot
# Processing Record 5 of Set 13 | liaozhong
# Processing Record 6 of Set 13 | imbituba
# Processing Record 7 of Set 13 | minot
# Processing Record 8 of Set 13 | helong
# Processing Record 9 of Set 13 | san martin
# Processing Record 10 of Set 13 | nizwa
# City not found. Skipping...
# Processing Record 11 of Set 13 | mikhaylovka
# Processing Record 12 of Set 13 | fare
# Processing Record 13 of Set 13 | san quintin
# Processing Record 14 of Set 13 | huanren
# Processing Record 15 of Set 13 | copperas cove
# Processing Record 16 of Set 13 | burica
# City not found. Skipping...
# Processing Record 17 of Set 13 | amapa
# Processing Record 18 of Set 13 | coihueco
# Processing Record 19 of Set 13 | grindavik
# Processing Record 20 of Set 13 | curanilahue
# Processing Record 21 of Set 13 | dzhebariki-khaya
# Processing Record 22 of Set 13 | angelholm
# City not found. Skipping...
# Processing Record 23 of Set 13 | tuy hoa
# Processing Record 24 of Set 13 | blyth
# Processing Record 25 of Set 13 | sao gabriel da cachoeira
# Processing Record 26 of Set 13 | rovaniemi
# Processing Record 27 of Set 13 | leh
# Processing Record 28 of Set 13 | noumea
# Processing Record 29 of Set 13 | acarau
# Processing Record 30 of Set 13 | korla
# Processing Record 31 of Set 13 | campbellton
# Processing Record 32 of Set 13 | fort nelson
# Processing Record 33 of Set 13 | svetlaya
# Processing Record 34 of Set 13 | mittagong
# Processing Record 35 of Set 13 | viesca
# Processing Record 36 of Set 13 | jalu
# Processing Record 37 of Set 13 | luziania
# Processing Record 38 of Set 13 | sompeta
# Processing Record 39 of Set 13 | xingcheng
# Processing Record 40 of Set 13 | vidim
# Processing Record 41 of Set 13 | sant feliu de guixols
# Processing Record 42 of Set 13 | faya
# Processing Record 43 of Set 13 | hazorasp
# Processing Record 44 of Set 13 | sur
# Processing Record 45 of Set 13 | tarakan
# Processing Record 46 of Set 13 | yar-sale
# Processing Record 47 of Set 13 | goshen
# Processing Record 48 of Set 13 | wakema
# Processing Record 49 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 13 | capao da canoa
# Processing Record 1 of Set 14 | marrakesh
# Processing Record 2 of Set 14 | hershey
# Processing Record 3 of Set 14 | cap malheureux
# Processing Record 4 of Set 14 | baturaja
# Processing Record 5 of Set 14 | ovsyanka
# Processing Record 6 of Set 14 | vallenar
# Processing Record 7 of Set 14 | tateyama
# Processing Record 8 of Set 14 | rudsar
# Processing Record 9 of Set 14 | gazojak
# Processing Record 10 of Set 14 | bahia blanca
# Processing Record 11 of Set 14 | parintins
# Processing Record 12 of Set 14 | meerzorg
# City not found. Skipping...
# Processing Record 13 of Set 14 | liuhe
# Processing Record 14 of Set 14 | guatire
# Processing Record 15 of Set 14 | kaeo
# Processing Record 16 of Set 14 | shimizu
# Processing Record 17 of Set 14 | ulaangom
# Processing Record 18 of Set 14 | imeni stepana razina
# Processing Record 19 of Set 14 | wangjing
# Processing Record 20 of Set 14 | samarai
# Processing Record 21 of Set 14 | pavlodolskaya
# Processing Record 22 of Set 14 | zorritos
# Processing Record 23 of Set 14 | chitral
# Processing Record 24 of Set 14 | launceston
# Processing Record 25 of Set 14 | requena
# Processing Record 26 of Set 14 | lagunas
# Processing Record 27 of Set 14 | shimoda
# Processing Record 28 of Set 14 | barguzin
# Processing Record 29 of Set 14 | maragogi
# Processing Record 30 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 14 | zholymbet
# Processing Record 32 of Set 14 | beloha
# Processing Record 33 of Set 14 | rengo
# Processing Record 34 of Set 14 | mastic beach
# Processing Record 35 of Set 14 | pangnirtung
# Processing Record 36 of Set 14 | deer lake
# Processing Record 37 of Set 14 | taixing
# Processing Record 38 of Set 14 | koumac
# Processing Record 39 of Set 14 | quzhou
# Processing Record 40 of Set 14 | dubna
# Processing Record 41 of Set 14 | labuhan
# Processing Record 42 of Set 14 | itapeva
# Processing Record 43 of Set 14 | bogdanovich
# Processing Record 44 of Set 14 | chimbote
# Processing Record 45 of Set 14 | amuntai
# Processing Record 46 of Set 14 | zapolyarnyy
# Processing Record 47 of Set 14 | visby
# Processing Record 48 of Set 14 | port arthur
# Processing Record 49 of Set 14 | tidore
# City not found. Skipping...
# Processing Record 50 of Set 14 | chicama
# Processing Record 1 of Set 15 | luganville
# Processing Record 2 of Set 15 | fort pierce
# Processing Record 3 of Set 15 | dunedin
# Processing Record 4 of Set 15 | angamacutiro
# City not found. Skipping...
# Processing Record 5 of Set 15 | mogzon
# Processing Record 6 of Set 15 | itarantim
# Processing Record 7 of Set 15 | gibara
# Processing Record 8 of Set 15 | yomitan
# City not found. Skipping...
# Processing Record 9 of Set 15 | bograd
# Processing Record 10 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 11 of Set 15 | timizart
# Processing Record 12 of Set 15 | sheltozero
# Processing Record 13 of Set 15 | victor harbor
# Processing Record 14 of Set 15 | maebaru
# Processing Record 15 of Set 15 | baykit
# Processing Record 16 of Set 15 | jawhar
# Processing Record 17 of Set 15 | mehamn
# Processing Record 18 of Set 15 | olafsvik
# Processing Record 19 of Set 15 | itarema
# Processing Record 20 of Set 15 | bukachacha
# Processing Record 21 of Set 15 | port hardy
# Processing Record 22 of Set 15 | kalanguy
# Processing Record 23 of Set 15 | scottsbluff
# Processing Record 24 of Set 15 | talas
# Processing Record 25 of Set 15 | give
# Processing Record 26 of Set 15 | balikpapan
# Processing Record 27 of Set 15 | kanbe
# Processing Record 28 of Set 15 | comodoro rivadavia
# Processing Record 29 of Set 15 | payson
# Processing Record 30 of Set 15 | contramaestre
# Processing Record 31 of Set 15 | tilichiki
# Processing Record 32 of Set 15 | general roca
# Processing Record 33 of Set 15 | sidi ali
# Processing Record 34 of Set 15 | batagay-alyta
# Processing Record 35 of Set 15 | banda aceh
# Processing Record 36 of Set 15 | biak
# Processing Record 37 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 38 of Set 15 | pangody
# Processing Record 39 of Set 15 | angra
# City not found. Skipping...
# Processing Record 40 of Set 15 | sept-iles
# Processing Record 41 of Set 15 | canberra
# Processing Record 42 of Set 15 | krasnogorsk
# Processing Record 43 of Set 15 | dudinka
# Processing Record 44 of Set 15 | falealupo
# City not found. Skipping...
# Processing Record 45 of Set 15 | ouadda
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Atuona      PF  -9.8000 -139.0333     80.13        74          85
# 1  Bambous Virieux      MU -20.3428   57.7575     75.20        94          75
# 2        Cape Town      ZA -33.9258   18.4232     63.00        88          75
# 3      Deputatskiy      RU  69.3000  139.9000     25.63        85          67
# 4     Longyearbyen      SJ  78.2186   15.6401     14.00        67          20
# 5     Punta Arenas      CL -53.1500  -70.9167     48.20        87          75
# 6          Iqaluit      CA  63.7506  -68.5145     33.80        86          90
# 7      Sungaipenuh      ID  -2.0833  101.3833     68.81        89         100
# 8           Kaseda      JP  31.4167  130.3167     62.60        42           0
# 9       Brokopondo      SR   4.7500  -55.1667     76.06        92         100
#
#    Wind Speed Current Description
# 0       15.46     overcast clouds
# 1       11.50          light rain
# 2       12.66       broken clouds
# 3        4.70       broken clouds
# 4        3.44          few clouds
# 5        3.44          light rain
# 6        3.15     overcast clouds
# 7        1.68     overcast clouds
# 8        9.22           clear sky
# 9        7.61     overcast clouds

# %%
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
